# %% [markdown]
# <a href="https://colab.research.google.com/github/kaikermaciel/python1/blob/main/dados_ttcc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np

# %%
repmd2016 = pd.read_csv("/content/csv_files/ICC110-2016-1-IE08.csv", sep = ";",encoding= 'iso-8859-1')
repmd2016
# Out:
#     ID_TURMA            DESCR_SITUACAO COD_TURMA  ID_PESSOA COD_CURSO  \
# 0     138253                  Aprovado      CB01     130413      IE08
# 1     138253        Reprovado por Nota      CB01     130406      IE08
# 2     138253  Reprovado por Freqüência      CB01     129393      IE08
# 3     138253                  Aprovado      CB01     130409      IE08
# 4     138253                  Aprovado      CB01     129247      IE08
# 5     138253                  Aprovado      CB01     130403      IE08
# 6     138253  Reprovado por Freqüência      CB01     128780      IE08
# 7     138253                  Aprovado      CB01     130416      IE08
# 8     138253  Reprovado por Freqüência      CB01     130417      IE08
# 9     138253        Reprovado por Nota      CB01     129392      IE08
# 10    138253  Reprovado por Freqüência      CB01     131338      IE08
# 11    138253                  Aprovado      CB01     132447      IE08
# ...

# %%
repmd2017 = pd.read_csv("/content/csv_files/ICC120-2017-1-IE08.csv", sep = ";",encoding= 'iso-8859-1')
repmd2017
# Out:
#     ID_TURMA            DESCR_SITUACAO COD_TURMA  ID_PESSOA COD_CURSO  \
# 0     152232        Reprovado por Nota      CB01     140910      IE08
# 1     152232                  Aprovado      CB01     138361      IE08
# 2     152232                  Aprovado      CB01     138762      IE08
# 3     152232        Reprovado por Nota      CB01     140398      IE08
# 4     152232        Reprovado por Nota      CB01     137971      IE08
# 5     152232        Reprovado por Nota      CB01     138765      IE08
# 6     152232        Reprovado por Nota      CB01     138362      IE08
# 7     152232        Reprovado por Nota      CB01     137190      IE08
# 8     152232        Reprovado por Nota      CB01     138772      IE08
# 9     152232        Reprovado por Nota      CB01     138770      IE08
# 10    152232        Reprovado por Nota      CB01     137187      IE08
# 11    152232        Reprovado por Nota      CB01     139920      IE08
# ...

# %%
repmd2018 = pd.read_csv("/content/csv_files/ICC120-2018-1-IE08.csv", sep = ";",encoding= 'iso-8859-1')
repmd2018
# Out:
#     ID_TURMA      DESCR_SITUACAO COD_TURMA ID_PESSOA COD_CURSO  \
# 0     167975            Aprovado      CB01    147305      IE08
# 1     167975            Aprovado      CB01    115440      IE08
# 2     167975            Aprovado      CB01    147306      IE08
# 3     167975            Aprovado      CB01    149210      IE08
# 4     167975            Aprovado      CB01    148102      IE08
# 5     167975            Aprovado      CB01    147307      IE08
# 6     167975            Aprovado      CB01    148511      IE08
# 7     167975  Reprovado por Nota      CB01    147308      IE08
# 8     167975            Aprovado      CB01      #N/D      IE08
# 9     167975            Aprovado      CB01    147852      IE08
# 10    167975            Aprovado      CB01    147309      IE08
# 11    167975            Aprovado      CB01    145630      IE08
# 12    167975            Aprovado      CB01    147310      IE08
# 13    167975            Aprovado      CB01    149328      IE08
# ...

# %%
repmd2019 = pd.read_csv("/content/csv_files/ICC120-2019-1-IE08-CB01.csv", sep = ";",encoding= 'iso-8859-1')
repmd2019
# Out:
#     ID_TURMA            DESCR_SITUACAO COD_TURMA  ID_PESSOA COD_CURSO  \
# 0     186540                  Aprovado      CB01     155664      IE08
# 1     186540                  Aprovado      CB01     155033      IE08
# 2     186540                  Aprovado      CB01     155069      IE08
# 3     186540                  Aprovado      CB01     155441      IE08
# 4     186540                  Aprovado      CB01     154721      IE08
# 5     186540                  Aprovado      CB01     154726      IE08
# 6     186540  Reprovado por Freqüência      CB01     131336      IE08
# 7     186540                  Aprovado      CB01     156832      IE08
# 8     186540  Reprovado por Freqüência      CB01     156590      IE08
# 9     186540        Reprovado por Nota      CB01     154080      IE08
# 10    186540                  Aprovado      CB01     154082      IE08
# 11    186540  Reprovado por Freqüência      CB01     149856      IE08
# ...

# %%
repmd2020 = pd.read_csv("/content/csv_files/ICC120-2020-ERE-IE08-CB01.csv", sep = ";",encoding = 'iso-8859-1')
repmd2020
# Out:
#     ID_TURMA DESCR_SITUACAO COD_TURMA ID_PESSOA COD_CURSO  \
# 0     216339       Aprovado      CB01    161983      IE08
# 1     216339       Aprovado      CB01    164680      IE08
# 2     216339       Aprovado      CB01      #N/D      IE08
# 3     216339       Aprovado      CB01    120031      IE08
# 4     216339       Aprovado      CB01      #N/D      IE08
# 5     216339       Aprovado      CB01    154080      IE08
# 6     216339       Aprovado      CB01    161593      IE08
# 7     216339       Aprovado      CB01    162801      IE08
# 8     216339       Aprovado      CB01    163465      IE08
# 9     216339       Aprovado      CB01    161672      IE08
# 10    216339       Aprovado      CB01    164684      IE08
# 11    216339       Aprovado      CB01    162707      IE08
# 12    216339       Aprovado      CB01    164686      IE08
# 13    216339       Aprovado      CB01    165660      IE08
# 14    216339       Aprovado      CB01    164689      IE08
# ...

# %%
repmd2021 = pd.read_csv("/content/csv_files/ICC120-2021-1-IE08-CB01.csv", sep = ";",encoding= 'iso-8859-1')
repmd2021
# Out:
#     ID_TURMA            DESCR_SITUACAO COD_TURMA  ID_PESSOA COD_CURSO  \
# 0     231461                  Aprovado      CB01     171017      IE08
# 1     231461  Reprovado por Freqüência      CB01     138959      IE08
# 2     231461        Reprovado por Nota      CB01     171035      IE08
# 3     231461                  Aprovado      CB01     172601      IE08
# 4     231461                  Aprovado      CB01     172021      IE08
# 5     231461                  Aprovado      CB01     172314      IE08
# 6     231461                  Aprovado      CB01     173154      IE08
# 7     231461                  Aprovado      CB01     172023      IE08
# 8     231461                  Aprovado      CB01     172025      IE08
# 9     231461                  Aprovado      CB01     130417      IE08
# 10    231461        Reprovado por Nota      CB01     172316      IE08
# 11    231461        Reprovado por Nota      CB01     171039      IE08
# ...

# %%
repmd2016['DESCR_SITUACAO'].replace({"Aprovado":1, "Reprovado por Nota": 0, "Reprovado por Freqüência":0},inplace = True)
repmd2017['DESCR_SITUACAO'].replace({"Aprovado":1, "Reprovado por Nota": 0, "Reprovado por Freqüência":0},inplace = True)
repmd2018['DESCR_SITUACAO'].replace({"Aprovado":1, "Reprovado por Nota": 0, "Reprovado por Freqüência":0},inplace = True)
repmd2019['DESCR_SITUACAO'].replace({"Aprovado":1, "Reprovado por Nota": 0, "Reprovado por Freqüência":0},inplace = True)
repmd2020['DESCR_SITUACAO'].replace({"Aprovado":1, "Reprovado por Nota": 0, "Reprovado por Freqüência":0},inplace = True)
repmd2021['DESCR_SITUACAO'].replace({"Aprovado":1, "Reprovado por Nota": 0, "Reprovado por Freqüência":0},inplace = True)

# %%
repmd2016['DESCR_SITUACAO'].value_counts().sort_index()
# Out:
# 0    26
# 1    29
# Name: DESCR_SITUACAO, dtype: int64

# %%
repmd2017['DESCR_SITUACAO'].value_counts().sort_index()
# Out:
# 0    35
# 1    20
# Name: DESCR_SITUACAO, dtype: int64

# %%
repmd2018['DESCR_SITUACAO'].value_counts().sort_index()
# Out:
# 0    12
# 1    46
# Name: DESCR_SITUACAO, dtype: int64

# %%
repmd2019['DESCR_SITUACAO'].value_counts().sort_index()
# Out:
# 0    23
# 1    33
# Name: DESCR_SITUACAO, dtype: int64

# %%
repmd2020['DESCR_SITUACAO'].value_counts().sort_index()
# Out:
# 1    25
# Name: DESCR_SITUACAO, dtype: int64

# %%
repmd2021['DESCR_SITUACAO'].value_counts().sort_index()
# Out:
# 0    17
# 1    40
# Name: DESCR_SITUACAO, dtype: int64

# %%
reprovageral = []
count = 0
for i in repmd2016['DESCR_SITUACAO']:
  if i == 0:
    count += 1 
reprovageral.append(count)
reprovageral
# Out:
# [26]

# %%
reprovageral
count = 0
for i in repmd2017['DESCR_SITUACAO']:
  if i == 0:
    count += 1 
reprovageral.append(count)
reprovageral
# Out:
# [26, 35]

# %%
reprovageral
count = 0
for i in repmd2018['DESCR_SITUACAO']:
  if i == 0:
    count += 1 
reprovageral.append(count)
reprovageral
# Out:
# [26, 35, 12]

# %%
reprovageral
count = 0
for i in repmd2019['DESCR_SITUACAO']:
  if i == 0:
    count += 1 
reprovageral.append(count)
reprovageral
# Out:
# [26, 35, 12, 23]

# %%
reprovageral
count = 0
for i in repmd2020['DESCR_SITUACAO']:
  if i == 0:
    count += 1 
reprovageral.append(count)
reprovageral
# Out:
# [26, 35, 12, 23, 0]

# %%
reprovageral
count = 0
for i in repmd2021['DESCR_SITUACAO']:
  if i == 0:
    count += 1 
reprovageral.append(count)
reprovageral
# Out:
# [26, 35, 12, 23, 0, 17]

# %%
anos = [2016,2017,2018,2019,2020,2021]

# %%
plt.title("Reprovações em Matemática Discreta")
plt.ylabel("Reprovados")
plt.xlabel("Anos")
plt.plot(anos,reprovageral, 'r')
plt.show()

# %%
repcalc12016 = pd.read_csv("/content/csv_files/IEM075-2016-1-IE08.csv", sep = ";", encoding= "iso-8859-1")
repcalc12016
# Out:
#     ID_TURMA            DESCR_SITUACAO COD_TURMA  ID_PESSOA COD_CURSO  \
# 0     137262        Reprovado por Nota      CB01     130413      IE08
# 1     137262        Reprovado por Nota      CB01     130406      IE08
# 2     137262  Reprovado por Freqüência      CB01     129393      IE08
# 3     137262        Reprovado por Nota      CB01     130409      IE08
# 4     137262        Reprovado por Nota      CB01     129247      IE08
# 5     137262        Reprovado por Nota      CB01     130403      IE08
# 6     137262  Reprovado por Freqüência      CB01     128780      IE08
# 7     137262        Reprovado por Nota      CB01     130416      IE08
# 8     137262        Reprovado por Nota      CB01     130417      IE08
# 9     137262        Reprovado por Nota      CB01     129392      IE08
# 10    137262        Reprovado por Nota      CB01     131338      IE08
# 11    137262                  Aprovado      CB01     132447      IE08
# ...

# %%
repcalc12017 = pd.read_csv("/content/csv_files/IEM075-2017-1-IE08.csv", sep = ";", encoding= "iso-8859-1")
repcalc12017
# Out:
#     ID_TURMA            DESCR_SITUACAO COD_TURMA  ID_PESSOA COD_CURSO  \
# 0     152231        Reprovado por Nota      CB01     140910      IE08
# 1     152231                  Aprovado      CB01     138361      IE08
# 2     152231                  Aprovado      CB01     138762      IE08
# 3     152231        Reprovado por Nota      CB01     140398      IE08
# 4     152231        Reprovado por Nota      CB01     137971      IE08
# 5     152231        Reprovado por Nota      CB01     138765      IE08
# 6     152231                  Aprovado      CB01     138362      IE08
# 7     152231        Reprovado por Nota      CB01     137190      IE08
# 8     152231        Reprovado por Nota      CB01     138770      IE08
# 9     152231                  Aprovado      CB01     137187      IE08
# 10    152231                  Aprovado      CB01     139920      IE08
# 11    152231  Reprovado por Freqüência      CB01     139621      IE08
# ...

# %%
repcalc12018 = pd.read_csv("/content/csv_files/IEM075-2018-1-IE08.csv", sep = ";", encoding= "iso-8859-1")
repcalc12018
# Out:
#     ID_TURMA            DESCR_SITUACAO COD_TURMA  ID_PESSOA COD_CURSO  \
# 0     167953        Reprovado por Nota      CB01     147305      IE08
# 1     167953                  Aprovado      CB01     147306      IE08
# 2     167953                  Aprovado      CB01     149210      IE08
# 3     167953        Reprovado por Nota      CB01     148102      IE08
# 4     167953                  Aprovado      CB01     147307      IE08
# 5     167953                  Aprovado      CB01     148511      IE08
# 6     167953                  Aprovado      CB01     147308      IE08
# 7     167953                  Aprovado      CB01     147852      IE08
# 8     167953                  Aprovado      CB01     147309      IE08
# 9     167953                  Aprovado      CB01     145630      IE08
# 10    167953                  Aprovado      CB01     147310      IE08
# 11    167953        Reprovado por Nota      CB01     149328      IE08
# ...

# %%
repcalc12019 = pd.read_csv("/content/csv_files/IEM075-2019-1-IE08.csv", sep = ";", encoding= "iso-8859-1")
repcalc12019
# Out:
#     ID_TURMA            DESCR_SITUACAO COD_TURMA  ID_PESSOA COD_CURSO  \
# 0     186521        Reprovado por Nota      CB01     155664      IE08
# 1     186521        Reprovado por Nota      CB01     155033      IE08
# 2     186521        Reprovado por Nota      CB01     155441      IE08
# 3     186521                  Aprovado      CB01     154721      IE08
# 4     186521        Reprovado por Nota      CB01     154726      IE08
# 5     186521        Reprovado por Nota      CB01     156832      IE08
# 6     186521  Reprovado por Freqüência      CB01     156590      IE08
# 7     186521        Reprovado por Nota      CB01     154080      IE08
# 8     186521        Reprovado por Nota      CB01     154082      IE08
# 9     186521  Reprovado por Freqüência      CB01     149856      IE08
# 10    186521  Reprovado por Freqüência      CB01     154077      IE08
# 11    186521        Reprovado por Nota      CB01     154079      IE08
# ...

# %%
repcalc12020 = pd.read_csv("/content/csv_files/IEM075-2020-ERE-IE08-CB01.csv", sep = ";", encoding= "iso-8859-1")
repcalc12020
# Out:
#     ID_TURMA DESCR_SITUACAO COD_TURMA ID_PESSOA COD_CURSO  \
# 0     216354       Aprovado      CB01    162634      IE08
# 1     216354       Aprovado      CB01    147305      IE08
# 2     216354       Aprovado      CB01    155664      IE08
# 3     216354       Aprovado      CB01    113245      IE08
# 4     216354       Aprovado      CB01    155033      IE08
# ..       ...            ...       ...       ...       ...
# 89    216354       Aprovado      CB01    155575      IE08
# 90    216354       Aprovado      CB01    161720      IE08
# 91    216354       Aprovado      CB01    155210      IE08
# 92    216354       Aprovado      CB01    162479      IE08
# 93    216354       Aprovado      CB01    157152      IE08
#
#                NOME_CURSO COD_ATIV_CURRIC                  NOME_ATIV_CURRIC  \
# 0   Ciência da Computação          IEM075  CÁLCULO DIFERENCIAL E INTEGRAL I
# 1   Ciência da Computação          IEM075  CÁLCULO DIFERENCIAL E INTEGRAL I
# ...

# %%
repcalc12021 = pd.read_csv("/content/csv_files/IEM075-2021-1-IE08.csv", sep = ";", encoding= "iso-8859-1")
repcalc12021
# Out:
#     ID_TURMA            DESCR_SITUACAO COD_TURMA  ID_PESSOA COD_CURSO  \
# 0     231513                  Aprovado      CB01     171017      IE08
# 1     231513                  Aprovado      CB01     171035      IE08
# 2     231513                  Aprovado      CB01     172601      IE08
# 3     231513                  Aprovado      CB01     172021      IE08
# 4     231513                  Aprovado      CB01     172314      IE08
# 5     231513                  Aprovado      CB01     173154      IE08
# 6     231513                  Aprovado      CB01     172023      IE08
# 7     231513                  Aprovado      CB01     172025      IE08
# 8     231513        Reprovado por Nota      CB01     172316      IE08
# 9     231513                  Aprovado      CB01     171039      IE08
# 10    231513                  Aprovado      CB01     169460      IE08
# 11    231513                  Aprovado      CB01     173764      IE08
# ...

# %%
repcalc12016['DESCR_SITUACAO'].replace({"Aprovado":1, "Reprovado por Nota": 0, "Reprovado por Freqüência":0},inplace = True)
repcalc12017['DESCR_SITUACAO'].replace({"Aprovado":1, "Reprovado por Nota": 0, "Reprovado por Freqüência":0},inplace = True)
repcalc12018['DESCR_SITUACAO'].replace({"Aprovado":1, "Reprovado por Nota": 0, "Reprovado por Freqüência":0},inplace = True)
repcalc12019['DESCR_SITUACAO'].replace({"Aprovado":1, "Reprovado por Nota": 0, "Reprovado por Freqüência":0},inplace = True)
repcalc12020['DESCR_SITUACAO'].replace({"Aprovado":1, "Reprovado por Nota": 0, "Reprovado por Freqüência":0},inplace = True)
repcalc12021['DESCR_SITUACAO'].replace({"Aprovado":1, "Reprovado por Nota": 0, "Reprovado por Freqüência":0},inplace = True)

# %%
repcalc12016['DESCR_SITUACAO'].value_counts().sort_index()
# Out:
# 0    37
# 1    17
# Name: DESCR_SITUACAO, dtype: int64

# %%
repcalc12017['DESCR_SITUACAO'].value_counts().sort_index()
# Out:
# 0    17
# 1    37
# Name: DESCR_SITUACAO, dtype: int64

# %%
repcalc12018['DESCR_SITUACAO'].value_counts().sort_index()
# Out:
# 0    19
# 1    37
# Name: DESCR_SITUACAO, dtype: int64

# %%
repcalc12019['DESCR_SITUACAO'].value_counts().sort_index()
# Out:
# 0    47
# 1     7
# Name: DESCR_SITUACAO, dtype: int64

# %%
repcalc12020['DESCR_SITUACAO'].value_counts().sort_index()
# Out:
# 1    94
# Name: DESCR_SITUACAO, dtype: int64

# %% [markdown]
# repcalc12021['DESCR_SITUACAO'].value_counts().sort_index()

# %%
reprovageralc = []
count = 0
for i in repcalc12016['DESCR_SITUACAO']:
  if i == 0:
    count += 1 
reprovageralc.append(count)
reprovageralc
# Out:
# [37]

# %%
reprovageralc
count = 0
for i in repcalc12017['DESCR_SITUACAO']:
  if i == 0:
    count += 1 
reprovageralc.append(count)
reprovageralc
# Out:
# [37, 17]

# %%
reprovageralc
count = 0
for i in repcalc12018['DESCR_SITUACAO']:
  if i == 0:
    count += 1 
reprovageralc.append(count)
reprovageralc
# Out:
# [37, 17, 19]

# %%
reprovageralc
count = 0
for i in repcalc12019['DESCR_SITUACAO']:
  if i == 0:
    count += 1 
reprovageralc.append(count)
reprovageralc
# Out:
# [37, 17, 19, 47]

# %%
reprovageralc
count = 0
for i in repcalc12020['DESCR_SITUACAO']:
  if i == 0:
    count += 1 
reprovageralc.append(count)
reprovageralc
# Out:
# [37, 17, 19, 47, 0]

# %%
reprovageralc
count = 0
for i in repcalc12021['DESCR_SITUACAO']:
  if i == 0:
    count += 1 
reprovageralc.append(count)
reprovageralc
# Out:
# [37, 17, 19, 47, 0, 5]

# %%
anos = [2016,2017,2018,2019,2020,2021]

# %%
plt.title("Reprovações em Cálculo I")
plt.ylabel("Reprovados")
plt.xlabel("Anos")
plt.plot(anos,reprovageralc, 'r')
plt.show()
